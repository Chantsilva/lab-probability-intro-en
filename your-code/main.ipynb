# %% [markdown]
# # Probability

# %% [markdown]
# ## Challenge 1
# There is a box with 10 white balls, 12 red balls and 8 black balls. Calculate the probability of:
# * Taking a white ball out.
# * Taking a white ball on first extraction and a black ball out on second extraction without replacing the first one.
# * Taking a white ball on first extraction and a black ball out on second extraction replacing the first one.
# * Taking 3 balls and them being all different colours.

# %%
from math import comb

# Data
white = 10 
red = 12
black = 8
total = white + red + black

# 1. White ball Probability
p1 = white / total

# 2. White first and then black without replacing
p2 = (white / total) * (black / (total - 1))

# 3. White first and then black and then replacing the white
p3 = (white / total) * (black / total)

# 4. 3 balls all different colours
total_combinations = comb(total, 3)
favorables = white * red * black  # comb(10,1)*comb(12,1)*comb(8,1)
p4 = favorables / total_combinations

# Result
print(f"1. P(white) = {p1:.4f} ({p1:.2%})")
print(f"2. P(white, black without replacement) = {p2:.5f} ({p2:.2%})")
print(f"3. P(white, black with replacement) = {p3:.5f} ({p3:.2%})")
print(f"4. P(3 different colours) = {p4:.5f} ({p4:.2%})")
# Out:
# 1. P(white) = 0.3333 (33.33%)
# 2. P(white, black without replacement) = 0.09195 (9.20%)
# 3. P(white, black with replacement) = 0.08889 (8.89%)
# 4. P(3 different colours) = 0.23645 (23.65%)

# %% [markdown]
# ## Challenge 2
#
# You want to go on picnic on Saturday. You hate rain, and would know to plan your weekend. To help you make a decision, you gather the following data about rainy days:
#
# * 40% of all days are cloudy.
# * About 50% of cloudy days are rainy.
# * About 20% of non-cloudy days are rainy.
#
# What is the chance of rain during next Saturday?

# %%
# Probabilities from the problem
P_C = 0.4          # Probability of cloudy day
P_R_given_C = 0.5  # Probability of rain given cloudy
P_R_given_NC = 0.2 # Probability of rain given not cloudy

# Calculate probability of NOT cloudy
P_NC = 1 - P_C

# Apply Law of Total Probability
# P(R) = P(R|C) * P(C) + P(R|NC) * P(NC)
P_R = (P_R_given_C * P_C) + (P_R_given_NC * P_NC)

# Display results
print("=== RAIN PROBABILITY CALCULATION ===")
print(f"Probability of cloudy day (P(C)): {P_C:.1%}")
print(f"Probability of rain if cloudy (P(R|C)): {P_R_given_C:.1%}")
print(f"Probability of rain if not cloudy (P(R|NC)): {P_R_given_NC:.1%}")
print(f"Probability of not cloudy (P(NC)): {P_NC:.1%}")
print("---")
print(f"FINAL RAIN PROBABILITY: {P_R:.1%} ({P_R:.2f})")
# Out:
# === RAIN PROBABILITY CALCULATION ===
# Probability of cloudy day (P(C)): 40.0%
# Probability of rain if cloudy (P(R|C)): 50.0%
# Probability of rain if not cloudy (P(R|NC)): 20.0%
# Probability of not cloudy (P(NC)): 60.0%
# ---
# FINAL RAIN PROBABILITY: 32.0% (0.32)

# %% [markdown]
# ## Challenge 3
#
# A and B are events of a probability such that $P(A) = 0.3$, $P(B) = 0.6$ and $P(A \cap B) = 0.1$
#
# Which of the following statements are true?
# **HINT: draw a big Venn Diagram by your side**
# * $P(\overline{A}) = 0.7$
# * $P(A \cup B) = 0.6$
# * $P(A \cap \overline{B}) = 0.2$
# * $P(A \cup \overline{A}) = 1$
# * $P(A \cap (B \cup \overline{B})) = 0.4$
# * $P(\overline{A} \cap \overline{B}) = 0.3$
# * $P(\overline{A \cap B}) = 0.9$

# %%
def check_probability_statements():
    # Given probabilities
    P_A = 0.3
    P_B = 0.6
    P_A_intersect_B = 0.1
    
    print("Given probabilities:")
    print(f"P(A) = {P_A}")
    print(f"P(B) = {P_B}")
    print(f"P(A ∩ B) = {P_A_intersect_B}")
    print("\n" + "="*50 + "\n")
    
    # Statement 1: P(not A) = 0.7
    P_not_A = 1 - P_A
    stmt1 = abs(P_not_A - 0.7) < 1e-10
    print(f"1. P(¬A) = {P_not_A} | Expected: 0.7 | {stmt1}")
    
    # Statement 2: P(A ∪ B) = 0.6
    P_A_union_B = P_A + P_B - P_A_intersect_B
    stmt2 = abs(P_A_union_B - 0.6) < 1e-10
    print(f"2. P(A ∪ B) = {P_A_union_B} | Expected: 0.6 | {stmt2}")
    
    # Statement 3: P(A ∩ not B) = 0.2
    P_A_intersect_notB = P_A - P_A_intersect_B
    stmt3 = abs(P_A_intersect_notB - 0.2) < 1e-10
    print(f"3. P(A ∩ ¬B) = {P_A_intersect_notB} | Expected: 0.2 | {stmt3}")
    
    # Statement 4: P(A ∪ not A) = 1
    P_A_union_notA = 1.0  # This is always true
    stmt4 = abs(P_A_union_notA - 1) < 1e-10
    print(f"4. P(A ∪ ¬A) = {P_A_union_notA} | Expected: 1 | {stmt4}")
    
    # Statement 5: P(A ∩ (B ∪ not B)) = 0.4
    # B ∪ not B is the entire sample space, so:
    P_A_intersect_universe = P_A
    stmt5 = abs(P_A_intersect_universe - 0.4) < 1e-10
    print(f"5. P(A ∩ (B ∪ ¬B)) = {P_A_intersect_universe} | Expected: 0.4 | {stmt5}")
    
    # Statement 6: P(not A ∩ not B) = 0.3
    P_notA_intersect_notB = 1 - P_A_union_B
    stmt6 = abs(P_notA_intersect_notB - 0.3) < 1e-10
    print(f"6. P(¬A ∩ ¬B) = {P_notA_intersect_notB} | Expected: 0.3 | {stmt6}")
    
    # Statement 7: P(not (A ∩ B)) = 0.9
    P_not_A_intersect_B = 1 - P_A_intersect_B
    stmt7 = abs(P_not_A_intersect_B - 0.9) < 1e-10
    print(f"7. P(¬(A ∩ B)) = {P_not_A_intersect_B} | Expected: 0.9 | {stmt7}")
    
    return [stmt1, stmt2, stmt3, stmt4, stmt5, stmt6, stmt7]

def main():
    results = check_probability_statements()
    
    print("\n" + "="*50)
    print("SUMMARY OF RESULTS:")
    print("="*50)
    
    true_statements = []
    for i, result in enumerate(results, 1):
        status = "TRUE" if result else "FALSE"
        print(f"Statement {i}: {status}")
        if result:
            true_statements.append(i)
    
    print(f"\nTrue statements: {true_statements}")
    
    # Additional verification using set operations concept
    print("\n" + "="*50)
    print("ADDITIONAL VERIFICATION:")
    print("="*50)
    
    P_A = 0.3
    P_B = 0.6
    P_A_intersect_B = 0.1
    
    # Calculate all regions of the Venn diagram
    only_A = P_A - P_A_intersect_B
    only_B = P_B - P_A_intersect_B
    neither = 1 - (only_A + only_B + P_A_intersect_B)
    
    print(f"Only A: {only_A}")
    print(f"Only B: {only_B}")
    print(f"Both A and B: {P_A_intersect_B}")
    print(f"Neither A nor B: {neither}")
    print(f"Sum check: {only_A + only_B + P_A_intersect_B + neither}")

if __name__ == "__main__":
    main()
# Out:
# Given probabilities:
# P(A) = 0.3
# P(B) = 0.6
# P(A ∩ B) = 0.1
#
# ...
#
# 1. P(¬A) = 0.7 | Expected: 0.7 | True
# 2. P(A ∪ B) = 0.7999999999999999 | Expected: 0.6 | False
# 3. P(A ∩ ¬B) = 0.19999999999999998 | Expected: 0.2 | True
# 4. P(A ∪ ¬A) = 1.0 | Expected: 1 | True
# 5. P(A ∩ (B ∪ ¬B)) = 0.3 | Expected: 0.4 | False
# 6. P(¬A ∩ ¬B) = 0.20000000000000007 | Expected: 0.3 | False
# 7. P(¬(A ∩ B)) = 0.9 | Expected: 0.9 | True
#
# ...
# SUMMARY OF RESULTS:
# ...
# Statement 1: TRUE
# Statement 2: FALSE
# Statement 3: TRUE
# Statement 4: TRUE
# Statement 5: FALSE
# Statement 6: FALSE
# Statement 7: TRUE
#
# True statements: [1, 3, 4, 7]
#
# ...
# ADDITIONAL VERIFICATION:
# ...
# Only A: 0.19999999999999998
# Only B: 0.5
# Both A and B: 0.1
# Neither A nor B: 0.20000000000000007
# Sum check: 1.0

# %% [markdown]
# ## Challenge 4
#
#  * If someone flies to China, the probability of getting Covid is 1%
#  * If someone flies to Italy, the probability of getting Covid is 20%
#
# I roll 1 dice with numbers 1, 2, 3, 4, 5, 6:
#  * If 1: I fly to Italy
#  * If not 1: I fly to China
#
# During my trip, I got Covid. What is the probability that I flew to China?

# %%
def covid_travel_bayes():
    print("=== COVID TRAVEL PROBABILITY PROBLEM ===\n")
    
    # Given probabilities
    P_I = 1/6          # Probability of flying to Italy (roll 1)
    P_C = 5/6          # Probability of flying to China (roll not 1)
    P_D_given_I = 0.20 # Probability of Covid given Italy
    P_D_given_C = 0.01 # Probability of Covid given China
    
    print("Given probabilities:")
    print(f"P(Italy) = {P_I:.4f}")
    print(f"P(China) = {P_C:.4f}")
    print(f"P(Covid | Italy) = {P_D_given_I}")
    print(f"P(Covid | China) = {P_D_given_C}")
    
    # Calculate total probability of getting Covid
    P_D = (P_D_given_C * P_C) + (P_D_given_I * P_I)
    print(f"\nP(Covid) = P(Covid|China)×P(China) + P(Covid|Italy)×P(Italy)")
    print(f"P(Covid) = ({P_D_given_C} × {P_C:.4f}) + ({P_D_given_I} × {P_I:.4f})")
    print(f"P(Covid) = {P_D_given_C * P_C:.4f} + {P_D_given_I * P_I:.4f}")
    print(f"P(Covid) = {P_D:.4f}")
    
    # Apply Bayes' Theorem: P(China | Covid)
    P_C_given_D = (P_D_given_C * P_C) / P_D
    
    print(f"\nApplying Bayes' Theorem:")
    print(f"P(China | Covid) = [P(Covid|China) × P(China)] / P(Covid)")
    print(f"P(China | Covid) = [{P_D_given_C} × {P_C:.4f}] / {P_D:.4f}")
    print(f"P(China | Covid) = {P_D_given_C * P_C:.4f} / {P_D:.4f}")
    print(f"P(China | Covid) = {P_C_given_D:.4f}")
    
    return P_C_given_D

def alternative_calculation():
    print("\n" + "="*50)
    print("ALTERNATIVE CALCULATION - Thinking in counts:")
    print("="*50)
    
    # Imagine 600 trips (to make numbers nice)
    n_trips = 600
    n_china = int((5/6) * n_trips)  # 500 trips
    n_italy = int((1/6) * n_trips)  # 100 trips
    
    print(f"Assume {n_trips} total trips:")
    print(f"  Trips to China: {n_china}")
    print(f"  Trips to Italy: {n_italy}")
    
    # Covid cases
    covid_china = int(n_china * 0.01)  # 1% of China trips
    covid_italy = int(n_italy * 0.20)  # 20% of Italy trips
    total_covid = covid_china + covid_italy
    
    print(f"\nCovid cases:")
    print(f"  From China trips: {n_china} × 1% = {covid_china}")
    print(f"  From Italy trips: {n_italy} × 20% = {covid_italy}")
    print(f"  Total Covid cases: {total_covid}")
    
    # Probability China given Covid
    P_C_given_D_count = covid_china / total_covid
    
    print(f"\nP(China | Covid) = China Covid cases / Total Covid cases")
    print(f"P(China | Covid) = {covid_china} / {total_covid}")
    print(f"P(China | Covid) = {P_C_given_D_count:.4f}")

def main():
    # Method 1: Direct Bayes calculation
    probability = covid_travel_bayes()
    
    print(f"\n🎯 FINAL ANSWER: {probability:.2f} or {probability:.1%}")
    
    # Method 2: Counting approach
    alternative_calculation()
    
    print("\n" + "="*50)
    print("CONCLUSION:")
    print("="*50)
    print("Even though you're much more likely to fly to China (5/6 probability),")
    print("the much higher Covid risk in Italy (20% vs 1%) means that")
    print("if you got Covid, there's only a 20% chance you flew to China.")

if __name__ == "__main__":
    main()
# Out:
# === COVID TRAVEL PROBABILITY PROBLEM ===
#
# Given probabilities:
# P(Italy) = 0.1667
# P(China) = 0.8333
# P(Covid | Italy) = 0.2
# P(Covid | China) = 0.01
#
# P(Covid) = P(Covid|China)×P(China) + P(Covid|Italy)×P(Italy)
# P(Covid) = (0.01 × 0.8333) + (0.2 × 0.1667)
# P(Covid) = 0.0083 + 0.0333
# P(Covid) = 0.0417
#
# Applying Bayes' Theorem:
# P(China | Covid) = [P(Covid|China) × P(China)] / P(Covid)
# P(China | Covid) = [0.01 × 0.8333] / 0.0417
# P(China | Covid) = 0.0083 / 0.0417
# P(China | Covid) = 0.2000
#
# 🎯 FINAL ANSWER: 0.20 or 20.0%
#
# ...
# ALTERNATIVE CALCULATION - Thinking in counts:
# ...
# Assume 600 total trips:
#   Trips to China: 500
#   Trips to Italy: 100
#
# Covid cases:
#   From China trips: 500 × 1% = 5
#   From Italy trips: 100 × 20% = 20
#   Total Covid cases: 25
#
# P(China | Covid) = China Covid cases / Total Covid cases
# P(China | Covid) = 5 / 25
# P(China | Covid) = 0.2000
#
# ...
# CONCLUSION:
# ...
# Even though you're much more likely to fly to China (5/6 probability),
# ...

# %% [markdown]
# ## BONUS
#
# You roll 2 dice. What is the probability that the sum of the numbers is 7? And 8? And 9? Then simulate 10000 times and draw a countplot.

# %% [markdown]
# your explanation here

# %%
# YOUR CODE HERE
